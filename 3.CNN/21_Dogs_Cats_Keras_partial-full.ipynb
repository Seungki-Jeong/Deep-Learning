# %% [markdown]
# # Dogs vs Cats

# %% [markdown]
# ## Kaggle Dataset의 일부를 이용한 개, 고양이 구분

# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dense, Flatten, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping
# Out:
# Using TensorFlow backend.

# %%
seed = 2020
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
path = 'dogs_cats/train_1/'

# %%
path_t = 'dogs_cats/test_1/'

# %%
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

dogs_t, cats_t = [], []
y_dogs_t, y_cats_t = [], []

# %%
dog_path = os.path.join(path, 'dog.*')
len(glob(dog_path))
# Out:
# 5000

# %%
dog_path_t = os.path.join(path_t, 'dog.*')
len(glob(dog_path_t))
# Out:
# 1250

# %%
dog_path = os.path.join(path, 'dog.*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
cat_path = os.path.join(path, 'cat.*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
dog_path_t = os.path.join(path_t, 'dog.*')
for dog_img in glob(dog_path_t):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs_t.append(dog)

# %%
cat_path_t = os.path.join(path_t, 'cat.*')
for dog_img in glob(dog_path_t):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    cats_t.append(dog)

# %%
classes = ['dog', 'cat']

# %%
plt.figure(figsize=(12,8))    
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))        
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
y_dogs_t = [1 for item in enumerate(dogs_t)]
y_cats_t = [0 for item in enumerate(cats_t)]

# %%
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
dogs_t = np.asarray(dogs_t).astype('float32') / 255
cats_t = np.asarray(cats_t).astype('float32') / 255
y_dogs_t = np.asarray(y_dogs_t).astype('int32')
y_cats_t = np.asarray(y_cats_t).astype('int32')

# %%
X_train = np.concatenate((dogs,cats), axis=0)
y_train = np.concatenate((y_dogs, y_cats), axis=0)

# %%
X_test = np.concatenate((dogs_t,cats_t), axis=0)
y_test = np.concatenate((y_dogs_t, y_cats_t), axis=0)

# %%
# len(X)

# %%
y_train = tf.keras.utils.to_categorical(y_train, 2)

# %%
y_test = tf.keras.utils.to_categorical(y_test, 2)

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Activation, BatchNormalization

# %%
weight_decay = 1e-6

# %%
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1), 
           activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(2, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 36864)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               18874880
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 18,940,898
# Trainable params: 18,940,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
# opt = tf.keras.optimizers.RMSprop(learning_rate=0.0001, decay=1e-6)

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer=Adam(), metrics=['accuracy'])

# %%
modelpath = "model/dogs_vs_cats-cnn-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %%
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# datagen = ImageDataGenerator(
#     rotation_range=15,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     horizontal_flip=True,
#     )
# datagen.fit(X_train)

# %%
X_train.shape, y_train.shape
# Out:
# ((10000, 96, 96, 1), (10000, 2))

# %%
# model.fit_generator(datagen.flow(X_train, y_train, batch_size=32),
#                     epochs=10,
#                     validation_data=(X_test, y_test),
#                     callbacks=[early_stopping_callback, checkpointer])

# %%
model.fit(X_train, y_train, batch_size=32, epochs=10, validation_split=0.2,
          callbacks=[checkpointer, early_stopping_callback])
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/10
# 8000/8000 [==============================] - 146s 18ms/step - loss: 0.6943 - accuracy: 0.6217 - val_loss: 0.8986 - val_accuracy: 0.2010
#
# Epoch 00001: val_loss improved from inf to 0.89860, saving model to model/dogs_vs_cats-cnn-01-0.8986.hdf5
# Epoch 2/10
# 8000/8000 [==============================] - 146s 18ms/step - loss: 0.6169 - accuracy: 0.6568 - val_loss: 0.8617 - val_accuracy: 0.3210
#
# Epoch 00002: val_loss improved from 0.89860 to 0.86166, saving model to model/dogs_vs_cats-cnn-02-0.8617.hdf5
# Epoch 3/10
# 8000/8000 [==============================] - 142s 18ms/step - loss: 0.5846 - accuracy: 0.6791 - val_loss: 1.0696 - val_accuracy: 0.2910
#
# Epoch 00003: val_loss did not improve from 0.86166
# Epoch 4/10
# 8000/8000 [==============================] - 142s 18ms/step - loss: 0.5339 - accuracy: 0.7249 - val_loss: 0.7617 - val_accuracy: 0.5775
#
# Epoch 00004: val_loss improved from 0.86166 to 0.76174, saving model to model/dogs_vs_cats-cnn-04-0.7617.hdf5
# Epoch 5/10
# 8000/8000 [==============================] - 143s 18ms/step - loss: 0.4657 - accuracy: 0.7722 - val_loss: 0.6233 - val_accuracy: 0.6815
#
# Epoch 00005: val_loss improved from 0.76174 to 0.62328, saving model to model/dogs_vs_cats-cnn-05-0.6233.hdf5
# Epoch 6/10
# 8000/8000 [==============================] - 147s 18ms/step - loss: 0.4065 - accuracy: 0.8189 - val_loss: 0.9252 - val_accuracy: 0.5735
#
# Epoch 00006: val_loss did not improve from 0.62328
# Epoch 7/10
# 8000/8000 [==============================] - 143s 18ms/step - loss: 0.3536 - accuracy: 0.8457 - val_loss: 0.8704 - val_accuracy: 0.5855
#
# Epoch 00007: val_loss did not improve from 0.62328
# Epoch 8/10
# 8000/8000 [==============================] - 143s 18ms/step - loss: 0.2819 - accuracy: 0.8798 - val_loss: 0.7264 - val_accuracy: 0.6815
#
# Epoch 00008: val_loss did not improve from 0.62328
# Epoch 9/10
# 8000/8000 [==============================] - 142s 18ms/step - loss: 0.2060 - accuracy: 0.9158 - val_loss: 0.9194 - val_accuracy: 0.6540
#
# Epoch 00009: val_loss did not improve from 0.62328
# Epoch 10/10
# 8000/8000 [==============================] - 143s 18ms/step - loss: 0.1548 - accuracy: 0.9366 - val_loss: 1.3499 - val_accuracy: 0.6045
#
# Epoch 00010: val_loss did not improve from 0.62328

# %%
from tensorflow.keras.models import load_model
# del model
model_1 = load_model('model/dogs_vs_cats-cnn-05-0.6233.hdf5')

# %%
X_test.shape, y_test.shape
# Out:
# ((2500, 96, 96, 1), (2500, 2))

# %%
scores = model_1.evaluate(X_test, y_test, verbose=1)
print('MODEL ACCURACY: %.5f' % scores[1])
# Out:
# 2500/2500 [==============================] - 7s 3ms/sample - loss: 1.1081 - accuracy: 0.5000
# MODEL ACCURACY: 0.50000
